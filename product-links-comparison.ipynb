# %%
import os
import base64
import requests
import cv2
import numpy as np
import random
import time
import csv
import pathlib
import textwrap
import pandas as pd
from PIL import Image
from PIL import PngImagePlugin

import google.generativeai as genai

api_key = 'AIzaSyC5TakQvuBGIidJ-44qSYodeSmhr8nw4dY'
genai.configure(api_key=api_key)

def encode_image(image):
    if image.dtype != np.uint8:
        image = (image * 255).astype(np.uint8)
    _, buffer = cv2.imencode('.jpg', image)
    return base64.b64encode(buffer).decode('utf-8')

# Define the directory
dir_path = r"/kaggle/input/image-dataset/multiple_smartphones.png"
example_image = Image.open(dir_path)
#scratch_train = Image.fromarray(scratch_train)

model = genai.GenerativeModel('gemini-1.5-pro-latest')
chat = model.start_chat(history=[])
response = chat.send_message([("Briefly describe the all the products in this image" 
                              "and provide direct links to purchase it or similar products"),
                                        example_image])
response.resolve()
print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...

# %%
import os
import base64
import requests
import cv2
import numpy as np
import random
import time
import csv
import pathlib
import textwrap
import pandas as pd
from PIL import Image
from PIL import PngImagePlugin

import google.generativeai as genai

api_key = 'AIzaSyC5TakQvuBGIidJ-44qSYodeSmhr8nw4dY'
genai.configure(api_key=api_key)

def encode_image(image):
    if image.dtype != np.uint8:
        image = (image * 255).astype(np.uint8)
    _, buffer = cv2.imencode('.jpg', image)
    return base64.b64encode(buffer).decode('utf-8')

# Define the directory
dir_path = r"/kaggle/input/image-dataset/electronics.jpeg"
example_image = Image.open(dir_path)
#scratch_train = Image.fromarray(scratch_train)

model = genai.GenerativeModel('gemini-1.5-pro-latest')
chat = model.start_chat(history=[])
response = chat.send_message([("Briefly describe the all the products in this image" 
                              "and provide direct links to purchase it or similar products"),
                                        example_image])
response.resolve()
print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...

# %%
import os
import base64
import requests
import cv2
import numpy as np
import random
import time
import csv
import pathlib
import textwrap
import pandas as pd
from PIL import Image
from PIL import PngImagePlugin

import google.generativeai as genai

api_key = 'AIzaSyC5TakQvuBGIidJ-44qSYodeSmhr8nw4dY'
genai.configure(api_key=api_key)

def encode_image(image):
    if image.dtype != np.uint8:
        image = (image * 255).astype(np.uint8)
    _, buffer = cv2.imencode('.jpg', image)
    return base64.b64encode(buffer).decode('utf-8')

# Define the directory
dir_path = r"/kaggle/input/image-dataset/2 red car.png"
example_image = Image.open(dir_path)
#scratch_train = Image.fromarray(scratch_train)

model = genai.GenerativeModel('gemini-1.5-pro-latest')
chat = model.start_chat(history=[])
response = chat.send_message([("Briefly describe the all the products in this image" 
                              "and provide direct links to purchase it or similar products"),
                                        example_image])
response.resolve()
print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...

# %% [markdown]
# ------------------------------------------------------Groq API and Llama 3.2 - 90 Billion Model------------------------------------------------------------------

# %%
# !pip install requests pillow

# %%
GROQ_API_KEY='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'

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import os

from groq import Groq

client = Groq(
    api_key=GROQ_API_KEY
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama3-8b-8192",
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models, also known as efficient language models or compact language models, are AI models that are designed to be faster and more compact than traditional language models while still maintaining their ability to generate high-quality text responses. The importance of fast language models cannot be overstated, as they have numerous applications in various industries, leading to significant economic and social benefits. Here are some reasons why fast language models are important:
#
# 1. **Scalability**: Fast language models can be deployed on low-power devices, such as smartphones, watches, or smart home devices, without compromising on performance. This enables widespread adoption and convenience for users.
# 2. **Real-time applications**: Fast language models can process and generate text in real-time, making them ideal for applications like chatbots, virtual assistants, and language translation services.
# ...

# %%
from groq import Groq

client = Groq(api_key=GROQ_API_KEY)
completion = client.chat.completions.create(
    model="llama-3.2-11b-vision-preview",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Fetch the product links for the product in the image?"
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://upload.wikimedia.org/wikipedia/commons/f/f2/LPU-v1-die.jpg"
                    }
                }
            ]
        }
    ],
    temperature=1,
    max_tokens=1024,
    top_p=1,
    stream=False,
    stop=None,
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content="I'm not able to access real-time information on the internet, so I cannot fetch the product links for the specific product in the image. However, I can suggest that you try searching for the product using its name or a descriptive phrase to find its online presence. You can also try checking online marketplaces or retailers that sell home decor items to find similar products.", role='assistant', function_call=None, tool_calls=None)

# %%
from groq import Groq
import base64


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "/kaggle/input/image-dataset/multiple_smartphones.png"
# Getting the base64 string
base64_image = encode_image(image_path)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "give the brand website links of the products in the images along with product description"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="llama-3.2-90b-vision-preview",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are the brand websites along with descriptions for the products in the images:
#
# **1. OnePlus 10 Pro**
#
# *   **Brand Website:** [www.oneplus.com](http://www.oneplus.com)
# *   **Description:** A high-end Android smartphone featuring a large AMOLED display, powerful Qualcomm Snapdragon processor, and advanced camera capabilities.
#
# **2. OnePlus 11**
#
# *   **Brand Website:** [www.oneplus.com](http://www.oneplus.com)
# *   **Description:** A flagship Android smartphone offering a sleek design, fast charging, and an impressive primary camera with optical zoom and wide-angle capabilities.
#
# **3. Apple iPhone 15 Pro Max**
#
# *   **Brand Website:** [www.apple.com](http://www.apple.com)
# *   **Description:** A premium iPhone model with a large OLED display, advanced camera system, and powerful A17 Bionic chip.
#
# **4. Samsung Galaxy S24 Ultra**
#
# *   **Brand Website:** [www.samsung.com](http://www.samsung.com)
# ...

# %%
from groq import Groq
import base64


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "/kaggle/input/image-dataset/electronics.jpeg"
base64_image = encode_image(image_path)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "give the brand website links of all the products in the images along with product description"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="llama-3.2-90b-vision-preview",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here is a list of products and their corresponding brand website links:
#
# 1. **Sony TV**
# 	* Brand Website: https://www.sony.com/
# 	* Product Type: LED TV
# 	* Features: 4K resolution, HDR, smart TV capabilities
# 2. **LG Fridge**
# 	* Brand Website: https://www.lg.com/
# 	* Product Type: French door refrigerator
# 	* Features: Energy efficient, ice maker, water dispenser
# 3. **Whirlpool Washing Machine**
# 	* Brand Website: https://www.whirlpool.com/
# 	* Product Type: Front load washing machine
# 	* Features: High efficiency, multiple cycle options
# 4. **Bosch Oven**
# 	* Brand Website: https://www.bosch-home.com/
# 	* Product Type: Convection oven
# 	* Features: Precision temperature control, multiple cooking modes
# 5. **Samsung Microwave**
# 	* Brand Website: https://www.samsung.com/
# 	* Product Type: Countertop microwave
# 	* Features: Sensor cooking, defrosting, and reheating
# 6. **Dyson Vacuum**
# 	* Brand Website: https://www.dyson.com/
# ...

# %%
from groq import Groq
import base64


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "//kaggle/input/image-dataset/2 red car.png"
base64_image = encode_image(image_path)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "give the brand website links of the 2 toyota and hyundai cars in the images along with product description"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="llama-3.2-90b-vision-preview",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are the brand website links and product descriptions for the two Toyota and Hyundai cars:
#
# **Toyota Corolla**
#
# * Brand Website: [www.toyota.com](http://www.toyota.com)
# * Product Description: The Toyota Corolla is a compact sedan that offers a comfortable ride, advanced safety features, and excellent fuel economy. It features a 1.8-liter 4-cylinder engine with up to 140 horsepower, and comes with a range of trim levels to suit different budgets and preferences.
#
# **Hyundai Elantra**
#
# * Brand Website: [www.hyundaiusa.com](http://www.hyundaiusa.com)
# * Product Description: The Hyundai Elantra is a compact sedan that boasts a sporty design, spacious interior, and cutting-edge technology features. It offers a 2.0-liter 4-cylinder engine with up to 147 horsepower, and comes with advanced safety features like forward collision avoidance assist and lane departure warning.
#
# ...

# %%
import os
import base64
import cv2
import numpy as np
from PIL import Image
import pytesseract

# Mock function for BLIP (replace with actual model if implemented)
def generate_blip_description(image_path):
    """
    Generates a description of an image using a mock BLIP model.
    """
    return "This is a mock BLIP-generated description of the image."

# OCR function using Tesseract
def extract_text_with_ocr(image_path):
    """
    Extracts text from an image using pytesseract.
    """
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"Image file not found at {image_path}")
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return pytesseract.image_to_string(gray_image)

# Integrating BLIP and OCR outputs
def integrate_blip_ocr(image_path):
    """
    Combines outputs from BLIP and OCR into a single textual description.
    """
    blip_description = generate_blip_description(image_path)
    ocr_text = extract_text_with_ocr(image_path)
    return f"{blip_description} Additionally, OCR detected: {ocr_text}"

# Gemini model integration (pseudo-code for sending a message)
def encode_image(image):
    """
    Encodes an image for sending to Gemini.
    """
    _, buffer = cv2.imencode('.jpg', image)
    encoded_image = base64.b64encode(buffer).decode('utf-8')
    return encoded_image

def generate_gemini_response(image_path, description):
    """
    Sends the image and description to the Gemini model and retrieves the response.
    """
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"Image file not found at {image_path}")
    encoded_image = encode_image(image)
    prompt = f"Based on the provided image and description: {description}, list all products visible in the image with purchase links."
    
    # Mock Gemini API call
    # chat = model.start_chat(history=[])  # Uncomment if using Gemini API
    # response = chat.send_message([prompt, encoded_image])  # Uncomment when Gemini API is available
    response = ""  # Placeholder for testing
    return response

# File path for testing
example_image_path = "/kaggle/input/image-dataset/multiple_smartphones.png"  # Replace with actual path

try:
    # Generate description
    combined_description = integrate_blip_ocr(example_image_path)

    # Get response from Gemini
    gemini_response = generate_gemini_response(example_image_path, combined_description)

    # Display results
    print("Combined Description:")
    print(combined_description)
    print("\nGemini Response:")
    print(gemini_response)
except Exception as e:
    print(f"An error occurred: {e}")
