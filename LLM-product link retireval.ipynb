# %%
# !pip install requests pillow
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (10.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.8.30)

# %%
GROQ_API_KEY='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'

# %%
# !pip install groq
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting groq
#   Downloading groq-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from groq) (2.9.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/conda/lib/python3.10/site-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq) (1.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq) (2.23.4)
# Downloading groq-0.12.0-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.12.0

# %%
import os

from groq import Groq

client = Groq(
    api_key=GROQ_API_KEY
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama3-8b-8192",
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models, also known as rapid language models or swift language models, have gained significant importance in recent years due to their ability to process large amounts of text data quickly and efficiently. Here are some reasons why fast language models are important:
#
# 1. **Scale and Speed**: Fast language models can process massive amounts of text data in a matter of seconds, making them ideal for applications that require rapid analysis, such as real-time sentiment analysis, entity recognition, and text classification.
# 2. **Batch Processing**: Fast language models can handle large batches of text data, enabling efficient processing of datasets that were previously cumbersome to handle with slower models.
# 3. **Real-time Applications**: Fast language models are crucial for real-time applications like chatbots, virtual assistants, and language translation services, where timely responses are essential.
# 4. **Scalability**: Fast language models can scale horizontally, allowing them to handle increasing volumes of data and traffic without sacrificing performance or accuracy.
# 5. **Cost-effectiveness**: Fast language models are often more cost-effective than traditional language models, as they require less computational power and can be trained on less data.
# 6. **Transfer Learning**: Fast language models can be pre-trained on large datasets and fine-tuned on smaller datasets, allowing for efficient transfer learning and adaptability to new tasks.
# 7. **Improved Accuracy**: Fast language models can leverage advances in deep learning techniques, such as attention mechanisms and transfer learning, to achieve higher accuracy and better performance on various NLP tasks.
# 8. **Enhanced Search and Retrieval**: Fast language models can enable efficient search and retrieval of text data, allowing users to quickly find relevant information and documents.
# 9. **Text Generation**: Fast language models can be used for text generation tasks, such as generating summaries, answers, and chat responses, at a rapid pace.
# 10. **Faster Development Cycles**: Fast language models can speed up the development cycles of NLP applications, reducing the time it takes to prototype and test new ideas.
#
# Some examples of fast language models include:
#
# 1. BERT (Bidirectional Encoder Representations from Transformers): A popular language model that uses a transformer architecture to process text data in a single pass.
# 2. T5 (Text-to-Text Transformer): A highly scalable language model designed for text generation and translation tasks.
# 3. RoBERTa (Robustly Optimized BERT Pretraining Approach): A variant of BERT that uses a different training approach and achieves state-of-the-art results on many NLP tasks.
#
# In summary, fast language models have revolutionized the field of natural language processing by enabling rapid processing, analysis, and generation of text data, making them essential for many applications and industries.

# %%
from groq import Groq

client = Groq(api_key=GROQ_API_KEY)
completion = client.chat.completions.create(
    model="llama-3.2-11b-vision-preview",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Fetch the product links for the product in the image?"
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://upload.wikimedia.org/wikipedia/commons/f/f2/LPU-v1-die.jpg"
                    }
                }
            ]
        }
    ],
    temperature=1,
    max_tokens=1024,
    top_p=1,
    stream=False,
    stop=None,
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content="I'm not able to fetch product links from an image as it is a visual representation and does not contain any interactive or searchable elements. However, I can suggest that you try searching for similar products online or checking the websites of retailers that sell furniture, or you can try scanning the QR code if there is one on the image to see if it links to a specific product page.", role='assistant', function_call=None, tool_calls=None)

# %%
from groq import Groq
import base64


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "/kaggle/input/4-smartphone/smartphone 2.jpg"

# Getting the base64 string
base64_image = encode_image(image_path)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "give the brand website links of the products in the images along with product description"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="llama-3.2-90b-vision-preview",
)

print(chat_completion.choices[0].message.content)
# Out:
# An image of various expensive smartphones is shown. Here are the individual devices, along with their corresponding brand website links and product descriptions:
#
# ### **Samsung S23 Ultra**
#
# *   **Brand Website:** [www.samsung.com](http://www.samsung.com/)
# *   **Product Description:** The Samsung S23 Ultra is a high-end smartphone featuring a large 6.8-inch Dynamic AMOLED display, a powerful Exynos 2100 chipset, and a long-lasting 5000mAh battery. It also boasts a quad-camera setup with a 108MP primary sensor, a 40MP front camera, and supports 5G connectivity.
#
# ### **OnePlus 11 Pro**
#
# *   **Brand Website:** [www.oneplus.com](http://www.oneplus.com/)
# *   **Product Description:** The OnePlus 11 Pro is a flagship smartphone with a 6.7-inch AMOLED display, a fast Qualcomm Snapdragon 8 Gen 1 chipset, and a large 5000mAh battery. It features a triple-camera setup with a 48MP primary sensor, a 16MP front camera, and supports fast charging and 5G connectivity.
#
# ### **Google Pixel 7 Pro**
#
# *   **Brand Website:** [store.google.com](http://store.google.com/)
# *   **Product Description:** The Google Pixel 7 Pro is a high-end smartphone with a 6.7-inch OLED display, a fast Google Tensor G2 chipset, and a long-lasting 5000mAh battery. It features a triple-camera setup with a 50MP primary sensor, a 12MP front camera, and supports 5G connectivity and timely software updates.
#
# ### **Samsung Galaxy S22 Ultra**
#
# *   **Brand Website:** [www.samsung.com](http://www.samsung.com/)
# *   **Product Description:** The Samsung Galaxy S22 Ultra is a flagship smartphone with a 6.8-inch Dynamic AMOLED display, a powerful Qualcomm Snapdragon 8 Gen 1 chipset, and a large 5000mAh battery. It features a quad-camera setup with a 108MP primary sensor, a 40MP front camera, and supports 5G connectivity.
#
# These smartphones are all high-end devices with advanced features and capabilities. They offer large displays, powerful processors, and advanced camera systems, making them suitable for users who want a premium smartphone experience.

# %%
from groq import Groq
import base64


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "/kaggle/input/red2car/2car.png"

# Getting the base64 string
base64_image = encode_image(image_path)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "give the brand website links of the products in the images along with product description"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="llama-3.2-90b-vision-preview",
)

print(chat_completion.choices[0].message.content)
# Out:
# Based on the image, I can identify the two red cars as a Toyota Corolla (on the left) and a Hyundai Elantra (on the right). However, please note that the accuracy of the product description is limited by the lack of clear visibility of the brand logos.
#
# Here are the brand website links along with a brief product description:
#
# **Toyota Corolla**
# * Website: https://www.toyota.com/corolla/
# * Description: The Toyota Corolla is a compact sedan known for its reliability, fuel efficiency, and affordability. It features a comfortable interior, advanced safety features, and a range of engine options.
#
# **Hyundai Elantra**
# * Website: https://www.hyundai.com/us/en/vehicles/elantra
# * Description: The Hyundai Elantra is a compact sedan that offers a stylish design, spacious interior, and a range of advanced safety and convenience features. It's available in various trim levels, including a sporty N Line model.

# %%
from groq import Groq
import base64


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "/kaggle/input/electronics/electronics.png"

# Getting the base64 string
base64_image = encode_image(image_path)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "give the brand website links of the products in the images along with product description"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="llama-3.2-90b-vision-preview",
)

print(chat_completion.choices[0].message.content)
# Out:
# I can provide you with a list of links to different home appliances and cleaning tools. Here are some popular brands and their websites:
#
# **Home Appliances:**
# * Refrigerators: https://www.whirlpool.com/
# * Air Conditioners: https://www.lg.com/
# * Microwave Ovens: https://www.panasonic.com/
# * Washing Machines: https://www.samsung.com/
# * Dryers: https://www.maytag.com/
# * Dishwashers: https://www.bosch-home.com/
# * Ovens/Stoves: https://www.geappliances.com/
# * Blenders: https://www.vitamix.com/
# * Coffee Makers: https://www.keurig.com/
#
# **Cleaning Tools:**
# * Vacuum Cleaners: https://www.dyson.com/
# * Mops: https://www.bissell.com/
# * Brooms: https://www.oreck.com/
# * Dustpans: https://www.eureka.com/
# * Cleaning Products: https://www.clorox.com/
#
# Please note that these are just a few examples, and there are many other brands and products available in the market. You can visit these websites to explore their product range and find the one that suits your needs.
