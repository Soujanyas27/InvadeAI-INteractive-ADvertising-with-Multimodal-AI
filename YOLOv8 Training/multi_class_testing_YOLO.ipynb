# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from scipy.interpolate import make_interp_spline
import multiprocessing as mp
from datetime import datetime
import yaml
import shutil

def create_output_folder():
    """Create timestamped output folder for results"""
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_dir = f'model_evaluation_results_{timestamp}'
    os.makedirs(output_dir, exist_ok=True)
    print(f"\nCreated output directory: {output_dir}")
    return output_dir

def calculate_iou(box1, box2):
    """Calculate IoU between two boxes [x1, y1, x2, y2]"""
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    
    intersection = max(0, x2 - x1) * max(0, y2 - y1)
    area1 = (box1[2] - box1[0]) * (box1[3] - box1[1])
    area2 = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union = area1 + area2 - intersection
    
    return intersection / union if union > 0 else 0

def load_class_descriptions(file_path):
    """Load class descriptions and filter for classes to use in model"""
    df = pd.read_csv(file_path)
    return df[df['UseInModel'] == True]

def load_and_filter_annotations(annotations_path, class_descriptions, image_dir, images_per_class=200):
    """Load and filter annotations based on available images and classes"""
    print("Loading annotations...")
    annotations_df = pd.read_csv(annotations_path)
    
    # Get valid class IDs
    valid_labels = class_descriptions['LabelName'].tolist()
    
    # Get available image IDs from the image directory
    available_images = {Path(f).stem for f in os.listdir(image_dir) 
                       if f.lower().endswith(('.jpg', '.jpeg', '.png'))}
    
    # Filter annotations for valid classes and available images
    filtered_df = annotations_df[
        (annotations_df['LabelName'].isin(valid_labels)) &
        (annotations_df['ImageID'].isin(available_images))
    ]
    
    # Select fixed number of images per class
    selected_images = set()
    class_image_dict = {}
    
    for class_id in valid_labels:
        # Get all images containing this class
        class_images = filtered_df[filtered_df['LabelName'] == class_id]['ImageID'].unique()
        
        # Ensure we have enough images
        if len(class_images) < images_per_class:
            print(f"Warning: Only {len(class_images)} images available for class {class_id}")
            selected = class_images
        else:
            # Randomly select fixed number of images
            selected = np.random.choice(class_images, images_per_class, replace=False)
        
        class_image_dict[class_id] = selected
        selected_images.update(selected)
    
    # Filter annotations to only include selected images
    final_df = filtered_df[filtered_df['ImageID'].isin(selected_images)].copy()
    
    print(f"Selected {len(selected_images)} unique images across all classes")
    for class_id in valid_labels:
        print(f"Class {class_id}: {len(class_image_dict[class_id])} images")
    
    return final_df, class_image_dict

def create_confidence_range():
    """Create a range of confidence thresholds with varying intervals"""
    conf_range = np.concatenate([
        np.arange(0.001, 0.01, 0.001),  # Fine sampling for 0.001-0.01
        np.arange(0.01, 0.03, 0.002),   # Medium sampling for 0.01-0.03
        np.arange(0.03, 0.1, 0.005),    # Coarser sampling for 0.03-0.1
        np.arange(0.1, 1.02, 0.02)      # Coarsest sampling for 0.1-1.0
    ])
    return np.unique(conf_range)

def process_single_image(args):
    """Process a single image and return its metrics"""
    print("process_single_image")
    try:
        image_path, model, confidence_range, ground_truth_df, target_class = args
        print(f"Processing {os.path.basename(image_path)}...")  # Progress tracking
        
        # Initialize results dictionary
        image_results = {conf: {
            'true_positives': 0,
            'false_positives': 0,
            'false_negatives': 0,
            'total_iou': 0,
            'total_predictions': 0,
            'confidence_scores': []
        } for conf in confidence_range}
        
        # Load image and get dimensions
        img = cv2.imread(image_path)
        if img is None:
            print(f"Failed to load image: {image_path}")
            return image_results
            
        height, width = img.shape[:2]
        
        # Get image ID and filter ground truth boxes
        image_id = Path(image_path).stem
        gt_boxes_df = ground_truth_df[
            (ground_truth_df['ImageID'] == image_id)
        ]
        if target_class is not None:
            gt_boxes_df = gt_boxes_df[gt_boxes_df['LabelName'] == target_class]
        
        # Convert ground truth boxes to pixel coordinates
        gt_boxes = []
        for _, row in gt_boxes_df.iterrows():
            gt_box = [
                int(row['XMin'] * width),
                int(row['YMin'] * height),
                int(row['XMax'] * width),
                int(row['YMax'] * height)
            ]
            gt_boxes.append(gt_box)
        
        # Get predictions
        preds = model.predict(image_path, conf=min(confidence_range))
        if len(preds) == 0 or len(preds[0].boxes) == 0:
            return image_results
            
        # Filter predictions for target class
        boxes = preds[0].boxes
        if target_class is not None:
            boxes = [box for box in boxes if int(box.cls) == target_class]
        
        # Process each confidence threshold
        for conf_threshold in confidence_range:
            high_conf_boxes = [box for box in boxes if float(box.conf) >= conf_threshold]
            
            true_positives = 0
            false_positives = 0
            total_iou = 0
            matched_gt = set()
            
            for box in high_conf_boxes:
                pred_box = box.xyxy[0].cpu().numpy()
                best_iou = 0
                best_gt_idx = -1
                
                for i, gt_box in enumerate(gt_boxes):
                    if i in matched_gt:
                        continue
                    iou = calculate_iou(pred_box, gt_box)
                    if iou > best_iou:
                        best_iou = iou
                        best_gt_idx = i
                
                total_iou += best_iou
                
                if best_iou > 0.5:
                    true_positives += 1
                    matched_gt.add(best_gt_idx)
                else:
                    false_positives += 1
            
            # Store results
            image_results[conf_threshold].update({
                'true_positives': true_positives,
                'false_positives': false_positives,
                'false_negatives': len(gt_boxes) - len(matched_gt),
                'total_iou': total_iou,
                'total_predictions': len(high_conf_boxes),
                'confidence_scores': [float(box.conf) for box in high_conf_boxes]
            })
        
        return image_results
        
    except Exception as e:
        print(f"Error processing image {image_path}: {str(e)}")
        return image_results

def analyze_class(model, image_paths, ground_truth_df, confidence_range, target_class):
    """Analyze model predictions for a specific class using sequential processing"""
    print(f"Processing {len(image_paths)} images...")
    
    # Initialize results
    combined_results = {conf: {
        'true_positives': 0,
        'false_positives': 0,
        'false_negatives': 0,
        'total_iou': 0,
        'total_predictions': 0
    } for conf in confidence_range}
    
    confidence_scores = {conf: [] for conf in confidence_range}
    
    # Process images sequentially
    for i, image_path in enumerate(image_paths, 1):
        print(f"Processing image {i}/{len(image_paths)}: {os.path.basename(image_path)}")
        
        try:
            # Get predictions
            preds = model.predict(image_path, conf=min(confidence_range))
            
            # Get image dimensions
            img = cv2.imread(image_path)
            if img is None:
                print(f"Failed to load image: {image_path}")
                continue
            height, width = img.shape[:2]
            
            # Get ground truth boxes
            image_id = Path(image_path).stem
            gt_boxes_df = ground_truth_df[ground_truth_df['ImageID'] == image_id]
            if target_class is not None:
                gt_boxes_df = gt_boxes_df[gt_boxes_df['LabelName'] == target_class]
            
            # Convert ground truth boxes to pixel coordinates
            gt_boxes = []
            for _, row in gt_boxes_df.iterrows():
                gt_box = [
                    int(row['XMin'] * width),
                    int(row['YMin'] * height),
                    int(row['XMax'] * width),
                    int(row['YMax'] * height)
                ]
                gt_boxes.append(gt_box)
            
            if len(preds) == 0 or len(preds[0].boxes) == 0:
                # No predictions for this image
                for conf in confidence_range:
                    combined_results[conf]['false_negatives'] += len(gt_boxes)
                continue
            
            # Filter predictions for target class if specified
            boxes = preds[0].boxes
            if target_class is not None:
                boxes = [box for box in boxes if int(box.cls) == target_class]
            
            # Process each confidence threshold
            for conf_threshold in confidence_range:
                high_conf_boxes = [box for box in boxes if float(box.conf) >= conf_threshold]
                
                true_positives = 0
                false_positives = 0
                total_iou = 0
                matched_gt = set()
                
                for box in high_conf_boxes:
                    pred_box = box.xyxy[0].cpu().numpy()
                    best_iou = 0
                    best_gt_idx = -1
                    
                    for i, gt_box in enumerate(gt_boxes):
                        if i in matched_gt:
                            continue
                        iou = calculate_iou(pred_box, gt_box)
                        if iou > best_iou:
                            best_iou = iou
                            best_gt_idx = i
                    
                    total_iou += best_iou
                    
                    if best_iou > 0.5:
                        true_positives += 1
                        matched_gt.add(best_gt_idx)
                    else:
                        false_positives += 1
                
                # Update combined results
                combined_results[conf_threshold]['true_positives'] += true_positives
                combined_results[conf_threshold]['false_positives'] += false_positives
                combined_results[conf_threshold]['false_negatives'] += (len(gt_boxes) - len(matched_gt))
                combined_results[conf_threshold]['total_iou'] += total_iou
                combined_results[conf_threshold]['total_predictions'] += len(high_conf_boxes)
                confidence_scores[conf_threshold].extend([float(box.conf) for box in high_conf_boxes])
                
        except Exception as e:
            print(f"Error processing image {image_path}: {str(e)}")
            continue
    
    return combined_results, confidence_scores

def plot_metrics(results, confidence_scores, class_name, save_path):
    """Plot and save metrics with curve fitting"""
    print(f"Plotting metrics for {class_name}...")
    thresholds = sorted(results.keys())
    metrics = {
        'precision': [],
        'recall': [],
        'f1': [],
        'iou': []
    }
    
    # Calculate metrics
    for threshold in thresholds:
        tp = results[threshold]['true_positives']
        fp = results[threshold]['false_positives']
        fn = results[threshold]['false_negatives']
        total_iou = results[threshold]['total_iou']
        num_pred = results[threshold]['total_predictions']
        
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        iou = total_iou / num_pred if num_pred > 0 else 0
        
        metrics['precision'].append(precision)
        metrics['recall'].append(recall)
        metrics['f1'].append(f1)
        metrics['iou'].append(iou)
    
    # Find optimal confidence threshold
    best_idx = np.argmax(metrics['f1'])
    best_threshold = thresholds[best_idx]
    
    # Create smooth curves using spline interpolation
    x_smooth = np.linspace(min(thresholds), max(thresholds), 300)
    curves = {}
    for metric in metrics:
        spline = make_interp_spline(thresholds, metrics[metric], k=3)
        curves[metric] = spline(x_smooth)
    
    # Plot
    plt.figure(figsize=(10, 6))
    colors = {'precision': 'blue', 'recall': 'red', 'f1': 'green', 'iou': 'purple'}
    
    for metric in metrics:
        plt.plot(thresholds, metrics[metric], f'o', color=colors[metric], alpha=0.5, markersize=4)
        plt.plot(x_smooth, curves[metric], '-', color=colors[metric], label=metric.capitalize())
    
    # Add vertical line at optimal threshold
    plt.axvline(x=best_threshold, color='gray', linestyle='--', alpha=0.5)
    plt.text(best_threshold, 0.5, f'Optimal conf={best_threshold:.3f}',
             rotation=90, verticalalignment='center')
    
    plt.xlabel('Confidence Threshold')
    plt.ylabel('Score')
    plt.title(f'Metrics vs Confidence Threshold - {class_name}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()
    
    return best_threshold, metrics

def draw_example_images(model, image_paths, ground_truth_df, class_name, 
                       conf_threshold, class_id, save_path):
    """Draw and save example images with predictions"""
    print(f"Creating example visualization for {class_name}...")
    fig, axes = plt.subplots(2, 4, figsize=(15, 8))
    fig.suptitle(f'Example Predictions for {class_name}\n' +
                 f'Confidence Threshold: {conf_threshold:.3f}', fontsize=12)
    
    for idx, (img_path, ax) in enumerate(zip(image_paths[:8], axes.flat)):
        # Load and convert image
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        height, width = img.shape[:2]
        
        # Get predictions
        results = model.predict(img_path, conf=conf_threshold)
        
        # Display image
        ax.imshow(img)
        
        # Draw predicted boxes
        if len(results) > 0:
            boxes = results[0].boxes
            for box in boxes:
                if int(box.cls) == class_id:  # Only draw boxes for target class
                    conf = float(box.conf)
                    x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
                    rect = plt.Rectangle((x1, y1), x2-x1, y2-y1,
                                      fill=False, color='red', linewidth=1)
                    ax.add_patch(rect)
                    ax.text(x1, y1-5, f'{conf:.2f}', color='red', fontsize=8)
        
        ax.set_axis_off()
        ax.set_title(f'Image: {Path(img_path).stem}', fontsize=8)
    
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()

def create_yolo_dataset_config(output_dir, class_descriptions, annotations_df, image_dir, class_image_dict=None):
    """Create YOLO format dataset configuration and label files"""
    print("Creating YOLO format dataset configuration...")
    
    # Create directories
    dataset_dir = os.path.join(output_dir, 'yolo_validation')
    images_dir = os.path.join(dataset_dir, 'images')
    labels_dir = os.path.join(dataset_dir, 'labels')
    os.makedirs(images_dir, exist_ok=True)
    os.makedirs(labels_dir, exist_ok=True)
    
    # Create class mapping - simpler version using DataFrame index
    class_map = {row['LabelName']: idx for idx, (_, row) in enumerate(class_descriptions.iterrows())}
    
    # Print class mapping for verification
    print("Class mapping:")
    for label, idx in class_map.items():
        print(f"{label}: {idx}")
    
    # Save class names file
    names_file = os.path.join(dataset_dir, 'classes.txt')
    with open(names_file, 'w') as f:
        for _, row in class_descriptions.iterrows():
            f.write(f"{row['DisplayName']}\n")
    
    # Filter images if class_image_dict is provided
    if class_image_dict is not None:
        valid_images = set().union(*class_image_dict.values())
        annotations_df = annotations_df[annotations_df['ImageID'].isin(valid_images)]
    
    # Process each unique image
    processed_images = set()
    for image_id in annotations_df['ImageID'].unique():
        if image_id in processed_images:
            continue
            
        # Source image path
        source_img_path = os.path.join(image_dir, f"{image_id}.jpg")
        if not os.path.exists(source_img_path):
            print(f"Warning: Image not found: {source_img_path}")
            continue
            
        # Create symbolic link to image
        dest_img_path = os.path.join(images_dir, f"{image_id}.jpg")
        if os.path.exists(dest_img_path):
            os.remove(dest_img_path)
        try:
            os.symlink(os.path.abspath(source_img_path), dest_img_path)
        except OSError as e:
            print(f"Warning: Could not create symlink, copying file instead: {e}")
            shutil.copy2(source_img_path, dest_img_path)
        
        # Get image dimensions
        img = cv2.imread(source_img_path)
        if img is None:
            print(f"Warning: Could not read image: {source_img_path}")
            continue
        height, width = img.shape[:2]
        
        # Create YOLO format label file
        img_annotations = annotations_df[annotations_df['ImageID'] == image_id]
        label_file = os.path.join(labels_dir, f"{image_id}.txt")
        
        with open(label_file, 'w') as f:
            for _, ann in img_annotations.iterrows():
                # Convert bbox to YOLO format (normalized coordinates)
                x_center = (ann['XMin'] + ann['XMax']) / 2
                y_center = (ann['YMin'] + ann['YMax']) / 2
                bbox_width = ann['XMax'] - ann['XMin']
                bbox_height = ann['YMax'] - ann['YMin']
                
                # Get class index
                try:
                    class_idx = class_map[ann['LabelName']]
                except KeyError:
                    print(f"Warning: Unknown class label {ann['LabelName']} for image {image_id}")
                    continue
                
                # Write YOLO format line: <class_idx> <x_center> <y_center> <width> <height>
                f.write(f"{class_idx} {x_center} {y_center} {bbox_width} {bbox_height}\n")
        
        processed_images.add(image_id)
    
    # Create dataset YAML configuration
    yaml_content = {
        'path': os.path.abspath(dataset_dir),
        'train': 'images',  # Not used but required
        'val': 'images',
        'names': {idx: row['DisplayName'] for idx, (_, row) in enumerate(class_descriptions.iterrows())}
    }
    
    yaml_path = os.path.join(dataset_dir, 'dataset.yaml')
    with open(yaml_path, 'w') as f:
        yaml.dump(yaml_content, f, sort_keys=False)
    
    print(f"Created YOLO dataset configuration in {dataset_dir}")
    print(f"Processed {len(processed_images)} images")
    print(f"Class names in YAML:")
    for idx, name in yaml_content['names'].items():
        print(f"{idx}: {name}")
    
    return yaml_path

def calculate_class_map50(model, yaml_path, class_idx):
    """Calculate mAP@50 for a specific class using YOLO's validator"""
    try:
        # Run validation for specific class
        metrics = model.val(data=yaml_path, split='val', classes=[class_idx])
        return metrics[0].maps  # Get mAP@50 for the class
    except Exception as e:
        print(f"Error calculating mAP@50: {str(e)}")
        return 0.0

# %%
print("Starting model evaluation...")

# Set random seed for reproducibility
np.random.seed(42)

# Create output directory
output_dir = create_output_folder()

# Load class descriptions
print("\nLoading class descriptions...")
class_desc_path = 'oidv7-class-descriptions-boxable.csv'
class_descriptions = load_class_descriptions(class_desc_path)
print(f"Found {len(class_descriptions)} classes to evaluate")

# Load annotations
print("\nLoading and filtering annotations...")
annotations_path = 'test-annotations-bbox.csv'
image_dir = 'image_data/test_images_25_class'

annotations_df, class_image_dict = load_and_filter_annotations(
    annotations_path, class_descriptions, image_dir, images_per_class=200)
print(f"Found {len(annotations_df)} relevant annotations")

# Load model
print("\nLoading YOLO model...")
model_path = 'E:/Data 255/YOLO multi-class/yolo_training/multi_class_run_4000_images_20241121_190831/yolo_boxes_4000/weights/best.pt'
model = YOLO(model_path)

# Create confidence range
confidence_range = create_confidence_range()
print(f"Created confidence range with {len(confidence_range)} thresholds")

# Create results dataframe
results_df = pd.DataFrame(columns=[
    'DisplayName', 'mAP@50', 'optimal_conf', 'f1', 'precision',
    'recall', 'mean_IoU', 'mAP'
])

# Process each class
print("\nProcessing individual classes...")
total_classes = len(class_descriptions)
yaml_path = create_yolo_dataset_config(
    output_dir, class_descriptions, annotations_df, image_dir, class_image_dict)

# Process each class
for idx, (_, class_row) in enumerate(class_descriptions.iterrows(), 1):
    class_name = class_row['DisplayName']
    class_id = class_row['LabelName']
    
    print(f"\nProcessing class {idx}/{total_classes}: {class_name}")
    
    # Get selected images for this class
    class_images = class_image_dict[class_id]
    image_paths = [
        os.path.join(image_dir, f"{img_id}.jpg")
        for img_id in class_images
    ]
    
    print(f"Using {len(image_paths)} images for {class_name}")
    
    # Analyze class
    results, confidence_scores = analyze_class(
        model, image_paths, annotations_df, confidence_range, class_id)
    
    # Plot metrics and get optimal threshold
    metrics_path = os.path.join(output_dir, f'metrics_{class_name}.png')
    opt_threshold, metrics = plot_metrics(
        results, confidence_scores, class_name, metrics_path)
    
    # Draw example images
    examples_path = os.path.join(output_dir, f'examples_{class_name}.png')
    draw_example_images(
        model, image_paths, annotations_df, class_name,
        opt_threshold, class_id, examples_path)
    
    # Calculate mAP@50
    print(f"Calculating mAP@50 for {class_name}...")
    map50 = calculate_class_map50(model, yaml_path, idx)
    
    # Add to results dataframe
    best_idx = np.argmax(metrics['f1'])
    results_df = pd.concat([results_df, pd.DataFrame([{
        'DisplayName': class_name,
        'mAP@50': map50,
        'optimal_conf': opt_threshold,
        'f1': metrics['f1'][best_idx],
        'precision': metrics['precision'][best_idx],
        'recall': metrics['recall'][best_idx],
        'mean_IoU': metrics['iou'][best_idx],
        'mAP': map50,
        'num_test_images': len(image_paths)
    }])], ignore_index=True)

# Calculate overall mAP@50
print("\nCalculating overall mAP@50...")
overall_metrics = model.val(data=yaml_path, split='val')
overall_map50 = overall_metrics[0].maps

# Save results to CSV
csv_path = os.path.join(output_dir, 'model_evaluation_results.csv')
results_df.to_csv(csv_path, index=False)

# Save selected image IDs for reproducibility
image_ids_df = pd.DataFrame({
    'class_id': [k for k, v in class_image_dict.items() for _ in v],
    'image_id': [img_id for v in class_image_dict.values() for img_id in v]
})
image_ids_df.to_csv(os.path.join(output_dir, 'selected_test_images.csv'), index=False)

# Print summary
print("\nModel Evaluation Results:")
print(results_df.to_string(index=False))

print(f"\nResults have been saved to: {output_dir}")
print("Files saved:")
print(f"- {csv_path} (metrics for all classes)")
print("- selected_test_images.csv (list of images used for testing)")
print("- metrics_*.png (confidence curves)")
print("- examples_*.png (example predictions)")
# Out:
# Starting model evaluation...
#
# Created output directory: model_evaluation_results_20241130_162103
#
# Loading class descriptions...
# Found 25 classes to evaluate
#
# Loading and filtering annotations...
# Loading annotations...
# Selected 4031 unique images across all classes
# Class /m/09j5n: 200 images
# Class /m/01xyhv: 200 images
# Class /m/0jyfg: 200 images
# Class /m/01d40f: 200 images
# Class /m/0fly7: 200 images
# Class /m/0h9mv: 200 images
# Class /m/0463sg: 200 images
# Class /m/0hg7b: 200 images
# Class /m/0342h: 200 images
# Class /m/0138tl: 200 images
# Class /m/01n5jq: 200 images
# Class /m/0271t: 200 images
# Class /m/01bqk0: 200 images
# Class /m/0c_jw: 200 images
# Class /m/02dgv: 200 images
# Class /m/032b3c: 200 images
# Class /m/052lwg6: 200 images
# Class /m/01y9k5: 200 images
# Class /m/02dl1y: 200 images
# Class /m/03120: 200 images
# Class /m/01bfm9: 200 images
# Class /m/04szw: 200 images
# Class /m/01n4qj: 200 images
# Class /m/0dv5r: 200 images
# Class /m/01599: 200 images
# Found 11661 relevant annotations
#
# Loading YOLO model...
# Created confidence range with 80 thresholds
#
# Processing individual classes...
# Creating YOLO format dataset configuration...
# Class mapping:
# /m/09j5n: 0
# /m/01xyhv: 1
# /m/0jyfg: 2
# /m/01d40f: 3
# /m/0fly7: 4
# /m/0h9mv: 5
# /m/0463sg: 6
# /m/0hg7b: 7
# /m/0342h: 8
# /m/0138tl: 9
# /m/01n5jq: 10
# /m/0271t: 11
# /m/01bqk0: 12
# /m/0c_jw: 13
# /m/02dgv: 14
# /m/032b3c: 15
# /m/052lwg6: 16
# /m/01y9k5: 17
# /m/02dl1y: 18
# /m/03120: 19
# /m/01bfm9: 20
# /m/04szw: 21
# /m/01n4qj: 22
# /m/0dv5r: 23
# /m/01599: 24
# Created YOLO dataset configuration in model_evaluation_results_20241130_162103\yolo_validation
# Processed 4031 images
# Class names in YAML:
# 0: Footwear
# 1: Suit
# 2: Glasses
# 3: Dress
# 4: Jeans
# 5: Tire
# 6: Fashion accessory
# 7: Microphone
# 8: Guitar
# 9: Toy
# 10: Poster
# 11: Drink
# 12: Bicycle wheel
# 13: Furniture
# 14: Door
# 15: Jacket
# 16: Baked goods
# 17: Desk
# 18: Hat
# 19: Flag
# 20: Shorts
# 21: Musical instrument
# 22: Shirt
# 23: Camera
# 24: Beer
#
# Processing class 1/25: Footwear
# Using 200 images for Footwear
# Processing 200 images...
# Processing image 1/200: 055aa9c8e194b5a4.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\055aa9c8e194b5a4.jpg: 640x480 45 Footwears, 1 Tire, 6 Fashion accessorys, 2 Toys, 3 Bicycle wheels, 1 Hat, 12 Shortss, 2 Musical instruments, 64.0ms
# Speed: 5.0ms preprocess, 64.0ms inference, 72.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 2/200: 05c77dd04223955b.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\05c77dd04223955b.jpg: 480x640 25 Footwears, 2 Glassess, 2 Fashion accessorys, 2 Microphones, 2 Toys, 1 Bicycle wheel, 3 Hats, 9 Shortss, 1 Musical instrument, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 3/200: 06aa36fae1159215.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\06aa36fae1159215.jpg: 640x640 10 Footwears, 8 Dresss, 19 Fashion accessorys, 3 Posters, 1 Shorts, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 4/200: 0dccda36775c66b5.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0dccda36775c66b5.jpg: 448x640 22 Footwears, 2 Tires, 4 Fashion accessorys, 1 Guitar, 2 Toys, 6 Drinks, 2 Furnitures, 2 Doors, 1 Baked goods, 1 Hat, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 5/200: 03b296f94a0f0fb4.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\03b296f94a0f0fb4.jpg: 448x640 189 Footwears, 2 Glassess, 33 Jeanss, 4 Furnitures, 67 Shortss, 5 Musical instruments, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 6/200: 266bbb9429bad4ed.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\266bbb9429bad4ed.jpg: 480x640 19 Footwears, 1 Glasses, 6 Jeanss, 7 Tires, 1 Fashion accessory, 1 Bicycle wheel, 11 Jackets, 1 Hat, 1 Flag, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 7/200: 004d6068f43bc436.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\004d6068f43bc436.jpg: 480x640 71 Footwears, 14 Suits, 2 Glassess, 2 Jeanss, 3 Posters, 10 Furnitures, 13 Doors, 10 Shirts, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 8/200: 430f3272c3dce728.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\430f3272c3dce728.jpg: 640x640 14 Footwears, 3 Dresss, 26 Fashion accessorys, 2 Toys, 1 Poster, 14 Furnitures, 5 Jackets, 2 Desks, 5 Hats, 3 Flags, 5 Musical instruments, 1 Beer, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 9/200: 077c11d1a3316450.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\077c11d1a3316450.jpg: 640x416 6 Footwears, 2 Fashion accessorys, 2 Shortss, 72.0ms
# Speed: 1.0ms preprocess, 72.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
# Processing image 10/200: 023e0c016fb05e7f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\023e0c016fb05e7f.jpg: 448x640 69 Footwears, 13 Jeanss, 4 Fashion accessorys, 2 Toys, 3 Jackets, 1 Hat, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 11/200: 04ccf8c5df047075.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\04ccf8c5df047075.jpg: 640x384 36 Footwears, 17 Jeanss, 2 Fashion accessorys, 4 Bicycle wheels, 8 Furnitures, 1 Shorts, 1 Shirt, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Processing image 12/200: 8db9be3f15f1cdda.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\8db9be3f15f1cdda.jpg: 448x640 52 Footwears, 34 Suits, 1 Dress, 26 Jeanss, 4 Fashion accessorys, 1 Poster, 1 Furniture, 3 Jackets, 2 Shortss, 23 Shirts, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 13/200: 1f41c866f60b8714.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\1f41c866f60b8714.jpg: 480x640 51 Footwears, 4 Suits, 3 Glassess, 1 Dress, 10 Jeanss, 1 Tire, 2 Fashion accessorys, 4 Posters, 1 Drink, 91 Furnitures, 19 Doors, 2 Jackets, 3 Desks, 2 Flags, 1 Musical instrument, 2 Shirts, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 14/200: 0ebbc76dc573f42a.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0ebbc76dc573f42a.jpg: 480x640 144 Footwears, 1 Suit, 95 Jeanss, 1 Fashion accessory, 1 Furniture, 22 Doors, 29 Jackets, 3 Hats, 2 Shortss, 2 Musical instruments, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 15/200: 0c9fd36ae8352220.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0c9fd36ae8352220.jpg: 640x480 22 Footwears, 12 Jeanss, 1 Tire, 6 Fashion accessorys, 1 Furniture, 1 Baked goods, 2 Hats, 2 Cameras, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 16/200: 41ebfb4544ad95d8.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\41ebfb4544ad95d8.jpg: 640x640 53 Footwears, 6 Glassess, 34 Jeanss, 2 Tires, 23 Fashion accessorys, 1 Poster, 1 Flag, 26 Shortss, 10 Shirts, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 17/200: 726d6108d31da15d.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\726d6108d31da15d.jpg: 480x640 55 Footwears, 19 Suits, 3 Glassess, 1 Dress, 6 Jeanss, 3 Fashion accessorys, 1 Poster, 1 Jacket, 1 Hat, 33 Flags, 1 Shorts, 9 Shirts, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 18/200: 292200f2f7fb1ce7.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\292200f2f7fb1ce7.jpg: 480x640 33 Footwears, 1 Dress, 49 Jeanss, 118 Tires, 7 Fashion accessorys, 3 Bicycle wheels, 2 Doors, 23 Jackets, 8 Shortss, 3 Musical instruments, 2 Shirts, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 19/200: 0a07c15f90208a8d.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0a07c15f90208a8d.jpg: 640x480 40 Footwears, 1 Glasses, 3 Dresss, 1 Jeans, 6 Tires, 13 Fashion accessorys, 22 Furnitures, 16 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 20/200: 49d9590f60056c84.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\49d9590f60056c84.jpg: 640x448 19 Footwears, 1 Jeans, 3 Fashion accessorys, 1 Microphone, 29 Bicycle wheels, 3 Hats, 1 Shorts, 104 Musical instruments, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 21/200: 00812a688e387d43.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\00812a688e387d43.jpg: 640x448 15 Footwears, 2 Glassess, 4 Fashion accessorys, 6 Shortss, 1 Shirt, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 22/200: 3073f524142d7ccd.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3073f524142d7ccd.jpg: 640x640 21 Footwears, 1 Glasses, 1 Dress, 12 Tires, 3 Fashion accessorys, 7 Toys, 2 Posters, 47 Furnitures, 7 Desks, 1 Flag, 1 Shorts, 2 Shirts, 12.0ms
# Speed: 5.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 23/200: 066af2f8fe78235f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\066af2f8fe78235f.jpg: 640x480 23 Footwears, 3 Glassess, 1 Dress, 56 Jeanss, 6 Fashion accessorys, 93 Toys, 4 Posters, 1 Drink, 36 Furnitures, 66 Jackets, 2 Baked goodss, 4 Desks, 3 Hats, 2 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 24/200: 3ca7f04576ff3ecd.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3ca7f04576ff3ecd.jpg: 480x640 6 Footwears, 19 Tires, 3 Posters, 118 Bicycle wheels, 17 Doors, 4 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 25/200: 00229645efaf204f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\00229645efaf204f.jpg: 640x608 125 Footwears, 2 Suits, 5 Glassess, 2 Dresss, 19 Jeanss, 4 Fashion accessorys, 9 Microphones, 1 Poster, 8 Jackets, 3 Hats, 1 Flag, 21 Shortss, 1 Musical instrument, 3 Shirts, 57.0ms
# Speed: 4.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
# Processing image 26/200: 32b8d99c7366fe5a.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\32b8d99c7366fe5a.jpg: 448x640 41 Footwears, 28 Shortss, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 27/200: 4f4cfcd4fcfd2f69.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\4f4cfcd4fcfd2f69.jpg: 416x640 37 Footwears, 2 Dresss, 1 Poster, 1 Jacket, 12 Shortss, 1 Shirt, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Processing image 28/200: 07c42e5882a169d5.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\07c42e5882a169d5.jpg: 384x640 110 Footwears, 1 Suit, 1 Glasses, 27 Jeanss, 1 Bicycle wheel, 7 Furnitures, 5 Jackets, 92 Shortss, 1 Shirt, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing image 29/200: 3237d36241ae17fb.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3237d36241ae17fb.jpg: 640x416 4 Footwears, 1 Glasses, 2 Jeanss, 13 Doors, 1 Shirt, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
# Processing image 30/200: 083a161a5796838f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\083a161a5796838f.jpg: 640x640 2 Footwears, 3 Fashion accessorys, 1 Toy, 1 Furniture, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 31/200: 568cce20f7e9bea0.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\568cce20f7e9bea0.jpg: 448x640 87 Footwears, 53 Jeanss, 83 Tires, 1 Fashion accessory, 8 Toys, 1 Poster, 3 Bicycle wheels, 9 Furnitures, 28 Jackets, 2 Hats, 18 Flags, 3 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 32/200: 45fbd451b4ee2e7a.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\45fbd451b4ee2e7a.jpg: 640x384 23 Footwears, 2 Glassess, 5 Fashion accessorys, 3 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Processing image 33/200: 4dcedce59fd8166e.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\4dcedce59fd8166e.jpg: 640x480 5 Footwears, 1 Glasses, 1 Dress, 4 Fashion accessorys, 16 Doors, 9 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 34/200: 28489e6014885554.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\28489e6014885554.jpg: 480x640 33 Footwears, 1 Jeans, 27 Tires, 110 Bicycle wheels, 2 Furnitures, 9 Flags, 40 Shortss, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 35/200: 06e2c22ca2b6d420.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\06e2c22ca2b6d420.jpg: 448x640 75 Footwears, 5 Glassess, 6 Dresss, 6 Tires, 11 Fashion accessorys, 4 Bicycle wheels, 38 Furnitures, 35 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 36/200: 0bd89d023568a67f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0bd89d023568a67f.jpg: 640x448 7 Footwears, 1 Dress, 11 Fashion accessorys, 2 Toys, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 37/200: 35a28b580bec9ad2.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\35a28b580bec9ad2.jpg: 640x576 60 Footwears, 3 Glassess, 1 Dress, 20 Jeanss, 1 Tire, 14 Fashion accessorys, 1 Poster, 1 Door, 33 Jackets, 1 Hat, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
# Processing image 38/200: 03de2a83847fb559.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\03de2a83847fb559.jpg: 448x640 25 Footwears, 1 Glasses, 3 Jeanss, 2 Fashion accessorys, 10 Posters, 7 Hats, 1 Flag, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 39/200: 03246a5e825f170d.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\03246a5e825f170d.jpg: 480x640 46 Footwears, 37 Jeanss, 57 Tires, 1 Poster, 1 Door, 26 Jackets, 32 Flags, 8 Shortss, 1 Shirt, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 40/200: 05c3f63584015220.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\05c3f63584015220.jpg: 480x640 47 Footwears, 43 Suits, 43 Jeanss, 28 Tires, 4 Toys, 1 Poster, 1 Drink, 14 Furnitures, 1 Door, 5 Jackets, 6 Desks, 5 Shirts, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 41/200: 0404bea3ac7150ca.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0404bea3ac7150ca.jpg: 448x640 28 Footwears, 13 Jeanss, 1 Jacket, 1 Hat, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 42/200: 05ef5702ffaf3cba.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\05ef5702ffaf3cba.jpg: 384x640 74 Footwears, 1 Glasses, 2 Dresss, 6 Jeanss, 5 Tires, 8 Fashion accessorys, 1 Furniture, 3 Jackets, 1 Baked goods, 23 Shortss, 1 Musical instrument, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing image 43/200: 01097eaa96dcfb20.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\01097eaa96dcfb20.jpg: 640x640 70 Footwears, 2 Dresss, 8 Jeanss, 2 Tires, 13 Fashion accessorys, 2 Posters, 6 Bicycle wheels, 1 Furniture, 1 Door, 2 Hats, 23 Shortss, 1 Musical instrument, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 44/200: 0346ee87f8490320.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0346ee87f8490320.jpg: 480x640 65 Footwears, 2 Suits, 19 Jeanss, 11 Furnitures, 2 Jackets, 38 Desks, 2 Flags, 16 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 45/200: 03199826c4aab1e3.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\03199826c4aab1e3.jpg: 576x640 50 Footwears, 1 Glasses, 6 Dresss, 1 Jeans, 2 Tires, 5 Fashion accessorys, 149 Furnitures, 8 Flags, 78 Shortss, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 640)
# Processing image 46/200: 2448583a1ce73fc6.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2448583a1ce73fc6.jpg: 640x640 6 Footwears, 14 Fashion accessorys, 4 Microphones, 1 Guitar, 1 Toy, 1 Poster, 1 Camera, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 47/200: 007de8d56e59900a.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\007de8d56e59900a.jpg: 640x448 50 Footwears, 3 Suits, 12 Dresss, 12 Fashion accessorys, 7 Microphones, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 48/200: 2f509e81d3d33ecc.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2f509e81d3d33ecc.jpg: 448x640 160 Footwears, 1 Glasses, 14 Jeanss, 6 Fashion accessorys, 7 Hats, 10 Flags, 102 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 49/200: 0998f953f99bf925.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0998f953f99bf925.jpg: 480x640 30 Footwears, 10 Suits, 39 Jeanss, 16 Tires, 1 Fashion accessory, 1 Bicycle wheel, 3 Furnitures, 5 Doors, 31 Jackets, 2 Shortss, 3 Musical instruments, 2 Shirts, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 50/200: 0310e61953ef7115.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0310e61953ef7115.jpg: 448x640 51 Footwears, 2 Glassess, 12 Jeanss, 49 Tires, 7 Fashion accessorys, 6 Furnitures, 3 Doors, 4 Hats, 5 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 51/200: 09d2374843129c2a.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\09d2374843129c2a.jpg: 448x640 59 Footwears, 6 Jeanss, 29 Tires, 4 Fashion accessorys, 11 Doors, 1 Jacket, 2 Hats, 3 Shortss, 1 Shirt, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 52/200: 3b5060a1cbfb9b59.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3b5060a1cbfb9b59.jpg: 640x480 6 Footwears, 1 Jeans, 1 Jacket, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 53/200: 36bf66b6a0a8fcbe.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\36bf66b6a0a8fcbe.jpg: 640x448 22 Footwears, 1 Dress, 3 Jeanss, 5 Fashion accessorys, 1 Poster, 2 Bicycle wheels, 1 Furniture, 1 Door, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 54/200: 38a4a5334beb3884.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\38a4a5334beb3884.jpg: 448x640 79 Footwears, 1 Glasses, 17 Dresss, 25 Jeanss, 1 Fashion accessory, 9 Microphones, 2 Doors, 4 Jackets, 30 Shortss, 3 Shirts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 55/200: 0334426756e025bc.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0334426756e025bc.jpg: 640x480 160 Footwears, 38 Jeanss, 1 Toy, 1 Bicycle wheel, 2 Doors, 3 Jackets, 1 Baked goods, 2 Hats, 1 Flag, 27 Shortss, 64 Musical instruments, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 56/200: 02ea0c95efbb4a91.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\02ea0c95efbb4a91.jpg: 448x640 27 Footwears, 21 Jeanss, 115 Tires, 2 Doors, 22 Jackets, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 57/200: 08fced60b9800b21.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\08fced60b9800b21.jpg: 640x448 49 Footwears, 1 Glasses, 3 Fashion accessorys, 2 Hats, 58 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 58/200: 02f2eb66e7befc62.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\02f2eb66e7befc62.jpg: 480x640 21 Footwears, 1 Dress, 2 Jeanss, 71 Tires, 2 Doors, 1 Shorts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 59/200: 17187ce0706cbb78.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\17187ce0706cbb78.jpg: 640x448 68 Footwears, 2 Glassess, 2 Fashion accessorys, 1 Hat, 53 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 60/200: 28735e68348358c3.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\28735e68348358c3.jpg: 480x640 45 Footwears, 2 Jeanss, 1 Fashion accessory, 10 Bicycle wheels, 1 Hat, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 61/200: 0dc9c6b1a0d95c70.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0dc9c6b1a0d95c70.jpg: 480x640 29 Footwears, 2 Dresss, 16 Tires, 1 Fashion accessory, 2 Microphones, 6 Toys, 15 Furnitures, 1 Door, 1 Jacket, 2 Hats, 2 Flags, 15 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 62/200: 0745beb7a3b3d4e3.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0745beb7a3b3d4e3.jpg: 448x640 6 Footwears, 15 Tires, 2 Toys, 1 Poster, 10 Bicycle wheels, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 63/200: 049ed008f5d01ff7.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\049ed008f5d01ff7.jpg: 640x480 125 Footwears, 5 Dresss, 23 Jeanss, 2 Fashion accessorys, 5 Flags, 121 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 64/200: 7fabba4e53945f6b.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\7fabba4e53945f6b.jpg: 640x480 11 Footwears, 1 Suit, 5 Tires, 1 Toy, 1 Poster, 4 Drinks, 1 Furniture, 1 Jacket, 2 Flags, 1 Musical instrument, 4 Cameras, 1 Beer, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 65/200: 54ec558e3e1b88dd.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\54ec558e3e1b88dd.jpg: 640x640 12 Footwears, 1 Suit, 4 Glassess, 1 Dress, 12 Jeanss, 14 Fashion accessorys, 2 Microphones, 1 Door, 20 Jackets, 2 Shortss, 1 Musical instrument, 3 Shirts, 9.0ms
# Speed: 5.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 66/200: 491c1cb38ae90679.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\491c1cb38ae90679.jpg: 384x640 44 Footwears, 2 Dresss, 4 Jeanss, 1 Toy, 4 Posters, 12 Bicycle wheels, 1 Baked goods, 41 Shortss, 10 Musical instruments, 1 Shirt, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing image 67/200: 061e5dd67eace597.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\061e5dd67eace597.jpg: 416x640 66 Footwears, 4 Suits, 9 Dresss, 4 Jeanss, 1 Fashion accessory, 6 Jackets, 2 Hats, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Processing image 68/200: 0c812c16ea400018.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0c812c16ea400018.jpg: 448x640 18 Footwears, 1 Fashion accessory, 13 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 69/200: 031ac8a5206fba86.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\031ac8a5206fba86.jpg: 480x640 48 Footwears, 1 Dress, 10 Jeanss, 11 Bicycle wheels, 2 Furnitures, 3 Doors, 13 Flags, 33 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 70/200: 35ab1cb11458b46b.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\35ab1cb11458b46b.jpg: 640x480 6 Footwears, 5 Suits, 1 Glasses, 1 Dress, 1 Jeans, 1 Microphone, 12 Posters, 2 Jackets, 1 Shorts, 1 Shirt, 1 Camera, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 71/200: 07174a860468f7c0.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\07174a860468f7c0.jpg: 480x640 145 Footwears, 4 Suits, 5 Glassess, 95 Jeanss, 1 Fashion accessory, 2 Furnitures, 14 Jackets, 1 Hat, 33 Shirts, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 72/200: 19f7b36f3b8e1c36.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\19f7b36f3b8e1c36.jpg: 640x448 30 Footwears, 2 Glassess, 15 Dresss, 1 Jeans, 23 Fashion accessorys, 1 Poster, 6 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 73/200: 02d75f015ac6ff33.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\02d75f015ac6ff33.jpg: 640x352 9 Footwears, 16 Dresss, 30 Fashion accessorys, 1 Toy, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Processing image 74/200: 041ad9ea598c47ad.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\041ad9ea598c47ad.jpg: 480x640 43 Footwears, 8 Tires, 4 Fashion accessorys, 19 Bicycle wheels, 19 Furnitures, 1 Door, 1 Jacket, 1 Hat, 11 Flags, 12 Shortss, 1 Musical instrument, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 75/200: 02888127ec7b0333.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\02888127ec7b0333.jpg: 576x640 23 Footwears, 1 Jeans, 2 Tires, 1 Bicycle wheel, 40 Furnitures, 1 Door, 14 Baked goodss, 29 Shortss, 2 Shirts, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 640)
# Processing image 76/200: 23f99d9632819b65.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\23f99d9632819b65.jpg: 448x640 117 Footwears, 4 Glassess, 4 Dresss, 15 Jeanss, 6 Fashion accessorys, 27 Furnitures, 1 Hat, 118 Shortss, 8 Musical instruments, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 77/200: 3dad27f92386e120.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3dad27f92386e120.jpg: 448x640 49 Footwears, 1 Glasses, 1 Dress, 1 Fashion accessory, 2 Hats, 123 Shortss, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 78/200: 1cd1e8ffa1903503.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\1cd1e8ffa1903503.jpg: 640x448 5 Footwears, 2 Suits, 1 Glasses, 2 Tires, 1 Poster, 1 Door, 4 Flags, 3 Shirts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 79/200: 3ad5c371bb15dab4.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3ad5c371bb15dab4.jpg: 576x640 49 Footwears, 7 Jeanss, 34 Bicycle wheels, 2 Shortss, 11.0ms
# Speed: 5.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 640)
# Processing image 80/200: 0133bac54fa0e077.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0133bac54fa0e077.jpg: 480x640 19 Footwears, 2 Jeanss, 194 Tires, 4 Jackets, 1 Shorts, 1 Shirt, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 81/200: 0393b4c75b8b1d2b.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0393b4c75b8b1d2b.jpg: 640x480 3 Footwears, 1 Jeans, 13 Tires, 5 Fashion accessorys, 1 Poster, 1 Furniture, 2 Jackets, 1 Hat, 1 Camera, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 82/200: 438a06167df517dd.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\438a06167df517dd.jpg: 640x608 24 Footwears, 4 Glassess, 22 Jeanss, 1 Tire, 5 Fashion accessorys, 1 Door, 5 Jackets, 20 Shortss, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
# Processing image 83/200: 001341ae9926808d.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\001341ae9926808d.jpg: 640x640 51 Footwears, 1 Suit, 7 Dresss, 1 Jeans, 6 Tires, 1 Fashion accessory, 11 Toys, 7 Posters, 71 Furnitures, 1 Jacket, 5 Hats, 60 Flags, 4 Shortss, 24 Musical instruments, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 84/200: 00848eefdb280a47.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\00848eefdb280a47.jpg: 448x640 4 Footwears, 4 Fashion accessorys, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 85/200: 3d8d1580be1deab5.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3d8d1580be1deab5.jpg: 640x448 9 Footwears, 1 Glasses, 1 Jeans, 2 Fashion accessorys, 1 Poster, 26 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 86/200: 00cd932265611688.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\00cd932265611688.jpg: 448x640 3 Footwears, 4 Dresss, 3 Tires, 12 Fashion accessorys, 1 Toy, 2 Bicycle wheels, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 87/200: 43028c395ed649ef.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\43028c395ed649ef.jpg: 640x448 30 Footwears, 6 Jeanss, 72 Bicycle wheels, 1 Hat, 1 Flag, 2 Shortss, 4 Musical instruments, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 88/200: 6c72c113aaa46606.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\6c72c113aaa46606.jpg: 640x640 28 Footwears, 4 Glassess, 2 Tires, 13 Fashion accessorys, 1 Microphone, 1 Bicycle wheel, 2 Hats, 8 Flags, 4 Shortss, 2 Musical instruments, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 89/200: 074f7f94415c923e.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\074f7f94415c923e.jpg: 448x640 16 Footwears, 1 Jeans, 44 Tires, 2 Toys, 6 Bicycle wheels, 1 Furniture, 3 Doors, 1 Jacket, 1 Shorts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 90/200: 074694b2b06afaa9.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\074694b2b06afaa9.jpg: 640x480 17 Footwears, 101 Tires, 5 Fashion accessorys, 2 Toys, 20 Bicycle wheels, 2 Jackets, 1 Shorts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 91/200: 4463b7ffc585bb9e.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\4463b7ffc585bb9e.jpg: 640x608 39 Footwears, 1 Dress, 2 Jeanss, 2 Tires, 7 Toys, 5 Posters, 1 Furniture, 1 Door, 30 Flags, 10 Shortss, 2 Musical instruments, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
# Processing image 92/200: 0e35b13e6a1bc70e.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0e35b13e6a1bc70e.jpg: 448x640 9 Footwears, 81 Tires, 13 Microphones, 117 Bicycle wheels, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 93/200: 00ac3ac45fb6a7d4.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\00ac3ac45fb6a7d4.jpg: 640x448 37 Footwears, 1 Suit, 9 Dresss, 1 Jeans, 25 Fashion accessorys, 2 Furnitures, 6 Shortss, 6 Musical instruments, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 94/200: 0bc9aabbca41a180.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0bc9aabbca41a180.jpg: 640x640 2 Footwears, 2 Tires, 49 Fashion accessorys, 2 Furnitures, 12.0ms
# Speed: 5.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 95/200: 1da35ffdf63ced85.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\1da35ffdf63ced85.jpg: 640x448 15 Footwears, 5 Jeanss, 6 Tires, 1 Fashion accessory, 1 Poster, 5 Jackets, 1 Hat, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 96/200: 00a011632563dae2.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\00a011632563dae2.jpg: 640x480 74 Footwears, 12 Jeanss, 12 Fashion accessorys, 1 Poster, 2 Furnitures, 4 Doors, 7 Flags, 77 Shortss, 27 Musical instruments, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 97/200: 370ef548a6c406bd.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\370ef548a6c406bd.jpg: 640x640 19 Footwears, 4 Jeanss, 15 Fashion accessorys, 1 Poster, 1 Door, 3 Jackets, 3 Flags, 5 Shortss, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 98/200: 016265035dfaffd3.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\016265035dfaffd3.jpg: 480x640 154 Footwears, 15 Dresss, 1 Jeans, 1 Fashion accessory, 1 Drink, 5 Jackets, 123 Shortss, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 99/200: 6931012dc5da9510.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\6931012dc5da9510.jpg: 480x640 48 Footwears, 33 Jeanss, 2 Tires, 20 Toys, 2 Drinks, 1 Bicycle wheel, 38 Furnitures, 9 Jackets, 8 Musical instruments, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 100/200: 158f9baff3439b59.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\158f9baff3439b59.jpg: 640x448 65 Footwears, 10 Dresss, 16 Tires, 86 Fashion accessorys, 4 Toys, 2 Furnitures, 21 Shortss, 2 Musical instruments, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 101/200: 01ab4be3f275d44c.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\01ab4be3f275d44c.jpg: 448x640 6 Footwears, 3 Shortss, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 102/200: 04488bf3f8e48e3b.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\04488bf3f8e48e3b.jpg: 640x512 59 Footwears, 79 Suits, 4 Glassess, 2 Jeanss, 1 Fashion accessory, 3 Furnitures, 1 Jacket, 6 Flags, 28 Shirts, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Processing image 103/200: 1fa1faa5108ec024.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\1fa1faa5108ec024.jpg: 640x480 2 Footwears, 2 Glassess, 1 Dress, 1 Drink, 2 Furnitures, 30 Doors, 2 Desks, 4 Shortss, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 104/200: 2cbb0020aa47cd35.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2cbb0020aa47cd35.jpg: 448x640 26 Footwears, 1 Dress, 1 Jeans, 2 Fashion accessorys, 5 Microphones, 5 Toys, 4 Jackets, 1 Musical instrument, 2 Cameras, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 105/200: 2b05ec6b8c6ca93f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2b05ec6b8c6ca93f.jpg: 480x640 64 Footwears, 5 Dresss, 37 Jeanss, 17 Fashion accessorys, 8 Furnitures, 1 Hat, 1 Flag, 27 Shortss, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 106/200: d275da1a80e6f815.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\d275da1a80e6f815.jpg: 384x640 5 Footwears, 2 Flags, 12 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing image 107/200: 2e45b2652f7e1f7f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2e45b2652f7e1f7f.jpg: 640x448 54 Footwears, 1 Glasses, 1 Dress, 1 Fashion accessory, 3 Hats, 93 Shortss, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 108/200: 164e11a8bf2279fa.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\164e11a8bf2279fa.jpg: 640x416 14 Footwears, 5 Fashion accessorys, 9 Shortss, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
# Processing image 109/200: 2674f1925c910521.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2674f1925c910521.jpg: 640x576 14 Footwears, 2 Suits, 1 Jeans, 1 Fashion accessory, 2 Microphones, 8 Posters, 4 Jackets, 8 Shirts, 29.0ms
# Speed: 4.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# Processing image 110/200: 39c2a2c5d470995c.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\39c2a2c5d470995c.jpg: 448x640 36 Footwears, 1 Dress, 1 Jeans, 6 Fashion accessorys, 3 Furnitures, 1 Jacket, 20 Shortss, 2 Shirts, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 111/200: 345a25af2eb65a6a.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\345a25af2eb65a6a.jpg: 480x640 15 Footwears, 1 Fashion accessory, 2 Bicycle wheels, 8 Doors, 1 Jacket, 23.0ms
# Speed: 4.5ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 112/200: 0674328470a04ed6.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0674328470a04ed6.jpg: 448x640 10 Footwears, 3 Jeanss, 14 Tires, 2 Toys, 5 Bicycle wheels, 2 Jackets, 1 Flag, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 113/200: 081bbb512c54decc.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\081bbb512c54decc.jpg: 416x640 131 Footwears, 5 Jeanss, 2 Fashion accessorys, 1 Toy, 1 Furniture, 1 Flag, 127 Shortss, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Processing image 114/200: 520ac5f11ebb926f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\520ac5f11ebb926f.jpg: 640x512 87 Footwears, 4 Glassess, 2 Jeanss, 7 Fashion accessorys, 12 Furnitures, 1 Jacket, 1 Hat, 65 Shortss, 6 Musical instruments, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
# Processing image 115/200: 2a12550a331c464f.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2a12550a331c464f.jpg: 448x640 53 Footwears, 6 Suits, 16 Dresss, 26 Jeanss, 10 Fashion accessorys, 2 Bicycle wheels, 9 Jackets, 17 Flags, 3 Shortss, 83 Musical instruments, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 116/200: a3318765b8a2e674.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\a3318765b8a2e674.jpg: 640x480 4 Footwears, 1 Glasses, 7 Dresss, 15 Fashion accessorys, 1 Toy, 3 Furnitures, 14 Shortss, 2 Shirts, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 117/200: 0cae86d3f12d6115.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0cae86d3f12d6115.jpg: 640x384 44 Footwears, 8 Dresss, 15 Jeanss, 8 Fashion accessorys, 3 Microphones, 1 Drink, 14 Furnitures, 4 Shortss, 1 Musical instrument, 1 Shirt, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Processing image 118/200: 3129706614e2add2.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3129706614e2add2.jpg: 640x448 31 Footwears, 6 Suits, 3 Glassess, 22 Dresss, 3 Jeanss, 29 Fashion accessorys, 9 Furnitures, 1 Shorts, 1 Shirt, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 119/200: 02e336b839d57849.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\02e336b839d57849.jpg: 640x480 10 Footwears, 1 Suit, 2 Jeanss, 1 Tire, 1 Fashion accessory, 3 Jackets, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 120/200: 2cbd4b706af1961b.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2cbd4b706af1961b.jpg: 480x640 18 Footwears, 2 Glassess, 2 Tires, 21 Bicycle wheels, 1 Hat, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 121/200: 1e9cb701520223a9.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\1e9cb701520223a9.jpg: 640x448 25 Footwears, 11 Suits, 7 Dresss, 2 Jeanss, 19 Fashion accessorys, 1 Poster, 1 Drink, 1 Door, 5 Hats, 13 Shirts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 122/200: 07a8a8e2e6fcd58e.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\07a8a8e2e6fcd58e.jpg: 384x640 10 Footwears, 1 Microphone, 2 Toys, 3 Posters, 6 Furnitures, 1 Desk, 14 Shortss, 12 Musical instruments, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing image 123/200: 40e17003c62445ed.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\40e17003c62445ed.jpg: 640x448 8 Footwears, 12 Doors, 2 Shortss, 10.0ms
# Speed: 3.6ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 124/200: 069cb88db5366b63.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\069cb88db5366b63.jpg: 448x640 85 Footwears, 4 Dresss, 10 Jeanss, 2 Fashion accessorys, 3 Jackets, 2 Hats, 2 Flags, 190 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 125/200: 3bb4084cde9b0366.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\3bb4084cde9b0366.jpg: 448x640 41 Footwears, 1 Glasses, 4 Jeanss, 7 Tires, 1 Fashion accessory, 8 Microphones, 2 Posters, 40 Furnitures, 16 Doors, 3 Jackets, 9 Desks, 1 Hat, 10 Musical instruments, 2 Cameras, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 126/200: 0b8442a9d20112b7.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0b8442a9d20112b7.jpg: 480x640 49 Footwears, 5 Dresss, 6 Tires, 1 Poster, 36 Furnitures, 11 Desks, 7 Shortss, 25 Musical instruments, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 127/200: 059520433a9809d0.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\059520433a9809d0.jpg: 416x640 153 Footwears, 2 Dresss, 4 Jeanss, 2 Bicycle wheels, 2 Furnitures, 1 Jacket, 84 Shortss, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Processing image 128/200: 2bb7d54aecf53850.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2bb7d54aecf53850.jpg: 480x640 21 Footwears, 2 Glassess, 7 Jeanss, 72 Tires, 5 Fashion accessorys, 1 Toy, 2 Posters, 29 Bicycle wheels, 1 Jacket, 13 Musical instruments, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 129/200: 2c4492ae2cd5b0fa.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2c4492ae2cd5b0fa.jpg: 480x640 69 Footwears, 13 Jeanss, 1 Poster, 1 Jacket, 2 Baked goodss, 2 Shirts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processing image 130/200: 48a2cbd7fd08eb0b.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\48a2cbd7fd08eb0b.jpg: 640x448 7 Footwears, 1 Suit, 1 Jeans, 9 Fashion accessorys, 1 Bicycle wheel, 3 Jackets, 4 Shirts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 131/200: 06ba1c4fcad1904a.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\06ba1c4fcad1904a.jpg: 448x640 34 Footwears, 32 Jeanss, 204 Posters, 22 Jackets, 1 Hat, 7 Flags, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 132/200: 352e1c7cfff08142.jpg
#
# ...
# Speed: 4.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 544)
# Processing image 181/200: 1ffc595d757b045a.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\1ffc595d757b045a.jpg: 640x512 2 Glassess, 1 Hat, 4 Shirts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Processing image 182/200: 000aa0b1c8fd5ddf.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\000aa0b1c8fd5ddf.jpg: 448x640 24 Footwears, 73 Dresss, 7 Tires, 7 Fashion accessorys, 14 Furnitures, 18 Doors, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 183/200: 125ed339d20d1675.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\125ed339d20d1675.jpg: 640x384 4 Dresss, 84 Fashion accessorys, 1 Poster, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Processing image 184/200: 29104100b7b6066b.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\29104100b7b6066b.jpg: 448x640 11 Footwears, 3 Suits, 2 Glassess, 22 Dresss, 11 Fashion accessorys, 2 Microphones, 53 Drinks, 17 Furnitures, 2 Doors, 54 Baked goodss, 3 Shirts, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 185/200: 0549efa561e016cd.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0549efa561e016cd.jpg: 640x448 4 Footwears, 1 Dress, 14 Fashion accessorys, 8 Shortss, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 186/200: 05386cd3059825b2.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\05386cd3059825b2.jpg: 640x448 12 Footwears, 18 Dresss, 19 Fashion accessorys, 2 Posters, 1 Hat, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 187/200: 041fd507c93b63fc.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\041fd507c93b63fc.jpg: 640x640 4 Suits, 10 Glassess, 3 Dresss, 18 Fashion accessorys, 4 Toys, 1 Poster, 1 Furniture, 1 Door, 4 Jackets, 2 Baked goodss, 4 Hats, 6 Flags, 1 Musical instrument, 12.0ms
# Speed: 5.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 188/200: 06aa36fae1159215.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\06aa36fae1159215.jpg: 640x640 10 Footwears, 8 Dresss, 19 Fashion accessorys, 3 Posters, 1 Shorts, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 189/200: 10ee52a80e64d0e3.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\10ee52a80e64d0e3.jpg: 640x352 5 Dresss, 57 Fashion accessorys, 1 Furniture, 3 Doors, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Processing image 190/200: 0f8549f66e05d39e.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0f8549f66e05d39e.jpg: 640x448 6 Footwears, 1 Dress, 6 Fashion accessorys, 11 Doors, 6 Shortss, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 191/200: 04326e59856f7816.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\04326e59856f7816.jpg: 640x640 4 Dresss, 25 Fashion accessorys, 1 Furniture, 1 Hat, 1 Shirt, 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 192/200: 0ab9605199e0cf3c.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0ab9605199e0cf3c.jpg: 448x640 12 Dresss, 11 Tires, 4 Fashion accessorys, 1 Poster, 2 Bicycle wheels, 7 Furnitures, 97 Jackets, 2 Hats, 16 Flags, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Processing image 193/200: 0c0a68d70f850506.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0c0a68d70f850506.jpg: 640x448 1 Footwear, 1 Dress, 25 Fashion accessorys, 3 Shortss, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Processing image 194/200: 10091a24ff3b5ea5.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\10091a24ff3b5ea5.jpg: 640x640 2 Dresss, 1 Jeans, 3 Fashion accessorys, 4 Microphones, 2 Toys, 1 Poster, 9 Drinks, 7 Furnitures, 1 Door, 2 Desks, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 195/200: 085780ba6fc1b06c.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\085780ba6fc1b06c.jpg: 640x640 9 Footwears, 2 Glassess, 1 Dress, 1 Jeans, 1 Tire, 4 Fashion accessorys, 1 Poster, 1 Drink, 1 Furniture, 12 Shortss, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing image 196/200: 04e59378fa44de12.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\04e59378fa44de12.jpg: 640x480 8 Dresss, 30 Fashion accessorys, 20.0ms
# Speed: 6.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 197/200: 0f3708bf3ae1b284.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0f3708bf3ae1b284.jpg: 640x480 12 Dresss, 181 Fashion accessorys, 8 Microphones, 2 Shortss, 1 Musical instrument, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Processing image 198/200: 106c3269cfb94e01.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\106c3269cfb94e01.jpg: 640x576 1 Footwear, 19 Dresss, 41 Fashion accessorys, 3 Furnitures, 1 Jacket, 2 Musical instruments, 22.0ms
# Speed: 7.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 576)
# Processing image 199/200: 32a93aaf703a7acb.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\32a93aaf703a7acb.jpg: 640x512 4 Footwears, 2 Glassess, 1 Furniture, 4 Doors, 1 Shorts, 1 Shirt, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Processing image 200/200: 0baacdd634ce76d9.jpg
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0baacdd634ce76d9.jpg: 640x448 4 Fashion accessorys, 3 Shirts, 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Plotting metrics for Dress...
# Creating example visualization for Dress...
# C:\Users\User\AppData\Local\Temp\ipykernel_58076\3597823495.py:359: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\124724830005d74a.jpg: 320x640 5 Footwears, 8 Dresss, 77 Fashion accessorys, 1 Poster, 3 Furnitures, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\512bba868790ca67.jpg: 640x512 1 Footwear, 5 Dresss, 1 Jeans, 46 Fashion accessorys, 10 Furnitures, 1 Door, 1 Jacket, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\1928189562dc619a.jpg: 448x640 28 Fashion accessorys, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\0812c925577193d4.jpg: 640x512 75 Footwears, 5 Suits, 7 Dresss, 30 Jeanss, 54 Fashion accessorys, 3 Bicycle wheels, 4 Furnitures, 16 Jackets, 1 Hat, 1 Flag, 22 Shortss, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\36ca2874955e46ea.jpg: 448x640 3 Dresss, 6 Fashion accessorys, 1 Poster, 2 Furnitures, 1 Door, 1 Shorts, 1 Shirt, 18 Cameras, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\2d778619f12c8aa1.jpg: 640x448 18 Footwears, 3 Dresss, 1 Jeans, 9 Fashion accessorys, 1 Jacket, 1 Shorts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\05b67510db584750.jpg: 640x448 47 Footwears, 19 Suits, 1 Glasses, 67 Dresss, 4 Jeanss, 30 Fashion accessorys, 9 Musical instruments, 2 Shirts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 e:\Data 255\YOLO multi-class\image_data\test_images_25_class\323d775085c0cd5e.jpg: 640x640 94 Footwears, 2 Glassess, 9 Dresss, 74 Jeanss, 4 Tires, 11 Fashion accessorys, 88 Jackets, 1 Hat, 17 Shortss, 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Calculating mAP@50 for Dress...
# Ultralytics 8.3.23  Python-3.10.0 torch-2.5.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# val: Scanning E:\Data 255\YOLO multi-class\model_evaluation_results_20241130_162103\yolo_validation\labels.cache... 4031 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4031/4031 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 78
#      76 # Calculate mAP@50
#      77 print(f"Calculating mAP@50 for {class_name}...")
# ---> 78 map50 = calculate_class_map50(model, yaml_path, idx)
#      80 # Add to results dataframe
#      81 best_idx = np.argmax(metrics['f1'])
#
# Cell In[10], line 511, in calculate_class_map50(model, yaml_path, class_idx)
#     508 """Calculate mAP@50 for a specific class using YOLO's validator"""
#     509 try:
#     510     # Run validation for specific class
# --> 511     metrics = model.val(data=yaml_path, split='val', classes=[class_idx])
#     512     return metrics[0].maps  # Get mAP@50 for the class
#     513 except Exception as e:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:635, in Model.val(self, validator, **kwargs)
#     632 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     634 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 635 validator(model=self.model)
#     636 self.metrics = validator.metrics
#     637 return validator.metrics
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\validator.py:155, in BaseValidator.__call__(self, trainer, model)
#     153     self.args.rect = False
#     154 self.stride = model.stride  # used in get_dataloader() for padding
# --> 155 self.dataloader = self.dataloader or self.get_dataloader(self.data.get(self.args.split), self.args.batch)
#     157 model.eval()
#     158 model.warmup(imgsz=(1 if pt else self.args.batch, 3, imgsz, imgsz))  # warmup
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\models\yolo\detect\val.py:244, in DetectionValidator.get_dataloader(self, dataset_path, batch_size)
#     242 """Construct and return dataloader."""
#     243 dataset = self.build_dataset(dataset_path, batch=batch_size, mode="val")
# --> 244 return build_dataloader(dataset, batch_size, self.args.workers, shuffle=False, rank=-1)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\data\build.py:135, in build_dataloader(dataset, batch, workers, shuffle, rank)
#     133 generator = torch.Generator()
#     134 generator.manual_seed(6148914691236517205 + RANK)
# --> 135 return InfiniteDataLoader(
#     136     dataset=dataset,
#     137     batch_size=batch,
#     138     shuffle=shuffle and sampler is None,
#     139     num_workers=nw,
#     140     sampler=sampler,
#     141     pin_memory=PIN_MEMORY,
#     142     collate_fn=getattr(dataset, "collate_fn", None),
#     143     worker_init_fn=seed_worker,
#     144     generator=generator,
#     145 )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\data\build.py:39, in InfiniteDataLoader.__init__(self, *args, **kwargs)
#      37 super().__init__(*args, **kwargs)
#      38 object.__setattr__(self, "batch_sampler", _RepeatSampler(self.batch_sampler))
# ---> 39 self.iterator = super().__iter__()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:484, in DataLoader.__iter__(self)
#     482     return self._iterator
#     483 else:
# --> 484     return self._get_iterator()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:415, in DataLoader._get_iterator(self)
#     413 else:
#     414     self.check_worker_number_rationality()
# --> 415     return _MultiProcessingDataLoaderIter(self)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:1138, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1131 w.daemon = True
#    1132 # NB: Process.start() actually take some time as it needs to
#    1133 #     start a process and pass the arguments over via a pipe.
#    1134 #     Therefore, we only add a worker to self._workers list after
#    1135 #     it started, so that we do not call .join() if program dies
#    1136 #     before it starts, and __del__ tries to join but will get:
#    1137 #     AssertionError: can only join a started process.
# -> 1138 w.start()
#    1139 self._index_queues.append(index_queue)
#    1140 self._workers.append(w)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\multiprocessing\context.py:327, in SpawnProcess._Popen(process_obj)
#     324 @staticmethod
#     325 def _Popen(process_obj):
#     326     from .popen_spawn_win32 import Popen
# --> 327     return Popen(process_obj)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\multiprocessing\popen_spawn_win32.py:93, in Popen.__init__(self, process_obj)
#      91 try:
#      92     reduction.dump(prep_data, to_child)
# ---> 93     reduction.dump(process_obj, to_child)
#      94 finally:
#      95     set_spawning_popen(None)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:
